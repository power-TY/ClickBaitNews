# %%
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/TM/train_result.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    epoch  steps  cossim_accuracy  cossim_accuracy_threshold  cossim_f1  \
# 0      0    182         0.843255                   0.752873   0.859415
# 1      0    364         0.872127                   0.693209   0.880912
# 2      0    546         0.894257                   0.749030   0.899290
# 3      0    728         0.901221                   0.708842   0.903724
# 4      0    910         0.902971                   0.745189   0.906563
#
#    cossim_precision  cossim_recall  cossim_f1_threshold  cossim_ap  \
# 0          0.775768       0.963281             0.745429   0.842152
# 1          0.823370       0.947103             0.691792   0.914094
# 2          0.853673       0.950057             0.734718   0.933655
# 3          0.877854       0.931165             0.702449   0.948418
# 4          0.866249       0.950812             0.728986   0.946119
#
#    manhattan_accuracy  ...  euclidean_recall  euclidean_f1_threshold  \
# 0            0.845553  ...          0.966063                8.256279
# 1            0.870531  ...          0.960499                9.554783
# 2            0.893176  ...          0.946828                8.973829
# 3            0.900895  ...          0.931165                9.530652
# 4            0.902594  ...          0.952186                9.158136
#
#    euclidean_ap  dot_accuracy  dot_accuracy_threshold    dot_f1  \
# 0      0.840371      0.838829               99.535362  0.855350
# 1      0.912401      0.871663               98.275711  0.878997
# 2      0.933413      0.892970              115.216988  0.897780
# 3      0.948213      0.898099              106.909615  0.901253
# 4      0.946233      0.899969              115.062927  0.903537
#
#    dot_precision  dot_recall  dot_f1_threshold    dot_ap
# 0       0.769761    0.962354         97.775787  0.841004
# 1       0.829558    0.934703         97.776306  0.911785
# 2       0.858280    0.941092        113.766937  0.931464
# 3       0.869847    0.935012        105.640976  0.946324
# 4       0.866970    0.943324        112.783554  0.941392
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   epoch                         55 non-null     int64
#  1   steps                         55 non-null     int64
#  2   cossim_accuracy               55 non-null     float64
#  3   cossim_accuracy_threshold     55 non-null     float64
#  4   cossim_f1                     55 non-null     float64
#  5   cossim_precision              55 non-null     float64
#  6   cossim_recall                 55 non-null     float64
#  7   cossim_f1_threshold           55 non-null     float64
#  8   cossim_ap                     55 non-null     float64
#  9   manhattan_accuracy            55 non-null     float64
#  10  manhattan_accuracy_threshold  55 non-null     float64
#  11  manhattan_f1                  55 non-null     float64
#  12  manhattan_precision           55 non-null     float64
#  13  manhattan_recall              55 non-null     float64
#  14  manhattan_f1_threshold        55 non-null     float64
#  15  manhattan_ap                  55 non-null     float64
#  16  euclidean_accuracy            55 non-null     float64
#  17  euclidean_accuracy_threshold  55 non-null     float64
#  18  euclidean_f1                  55 non-null     float64
#  19  euclidean_precision           55 non-null     float64
#  20  euclidean_recall              55 non-null     float64
#  21  euclidean_f1_threshold        55 non-null     float64
#  22  euclidean_ap                  55 non-null     float64
#  23  dot_accuracy                  55 non-null     float64
#  24  dot_accuracy_threshold        55 non-null     float64
#  25  dot_f1                        55 non-null     float64
#  26  dot_precision                 55 non-null     float64
#  27  dot_recall                    55 non-null     float64
#  28  dot_f1_threshold              55 non-null     float64
#  29  dot_ap                        55 non-null     float64
# dtypes: float64(28), int64(2)
# memory usage: 13.0 KB

# %%
use_col=['cossim_accuracy', 'manhattan_accuracy', 'euclidean_accuracy', 'dot_accuracy']

df_final=df[use_col]

# %%
df_final
# Out:
#     cossim_accuracy  manhattan_accuracy  euclidean_accuracy  dot_accuracy
# 0          0.843255            0.845553            0.843289      0.838829
# 1          0.872127            0.870531            0.871029      0.871663
# 2          0.894257            0.893176            0.894136      0.892970
# 3          0.901221            0.900895            0.901462      0.898099
# 4          0.902971            0.902594            0.903143      0.899969
# 5          0.910965            0.910777            0.911274      0.908221
# 6          0.914671            0.914757            0.914843      0.911789
# 7          0.917141            0.916369            0.917004      0.915717
# 8          0.917570            0.916798            0.917399      0.915340
# 9          0.915289            0.914585            0.915014      0.912955
# 10         0.916764            0.916163            0.916421      0.913933
# 11         0.920435            0.920555            0.920812      0.917639
# 12         0.920538            0.920349            0.920624      0.919148
# 13         0.921756            0.921807            0.921842      0.918531
# 14         0.921482            0.921276            0.921396      0.919440
# 15         0.924913            0.924398            0.924552      0.922974
# 16         0.923969            0.924089            0.924329      0.920692
# 17         0.925650            0.926251            0.925822      0.922065
# 18         0.927057            0.926508            0.926577      0.925976
# 19         0.927211            0.927091            0.927177      0.925221
# 20         0.926765            0.926010            0.926233      0.925736
# 21         0.927297            0.926628            0.926714      0.926045
# 22         0.928292            0.927880            0.928018      0.926028
# 23         0.927657            0.927126            0.926971      0.926233
# 24         0.928738            0.928120            0.928464      0.927349
# 25         0.928446            0.928241            0.928344      0.926354
# 26         0.927863            0.927795            0.928000      0.925770
# 27         0.928155            0.928429            0.928481      0.926148
# 28         0.926251            0.926559            0.925976      0.923712
# 29         0.929956            0.929990            0.930042      0.928807
# 30         0.930076            0.930076            0.930076      0.927674
# 31         0.930882            0.930213            0.930677      0.929613
# 32         0.930762            0.930248            0.930539      0.929253
# 33         0.929887            0.930042            0.929939      0.928687
# 34         0.930025            0.929733            0.929922      0.928326
# 35         0.931226            0.930831            0.930917      0.929990
# 36         0.930059            0.929030            0.929390      0.928824
# 37         0.930677            0.930402            0.930642      0.929304
# 38         0.930745            0.930677            0.930814      0.928120
# 39         0.930848            0.930677            0.930179      0.928481
# 40         0.930454            0.930454            0.930419      0.928069
# 41         0.930848            0.931003            0.931054      0.928910
# 42         0.931740            0.931620            0.931672      0.930333
# 43         0.931809            0.931603            0.931826      0.930299
# 44         0.931363            0.931311            0.931414      0.930059
# 45         0.930762            0.930882            0.930780      0.929304
# 46         0.931037            0.931140            0.931157      0.928892
# 47         0.931431            0.931466            0.931534      0.929579
# 48         0.931431            0.931775            0.931551      0.929853
# 49         0.930677            0.930968            0.930814      0.929373
# 50         0.931569            0.931672            0.931757      0.930025
# 51         0.931603            0.931654            0.931792      0.929767
# 52         0.931431            0.931328            0.931397      0.929304
# 53         0.931346            0.931466            0.931483      0.929476
# 54         0.931346            0.931466            0.931483      0.929476

# %%
fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

for i in use_col:
  ax.plot(df_final[i], label=i) ## 선그래프 생성
plt.legend()

plt.ylim([0.9, 0.935])

plt.title('ACC',fontsize=20) ## 타이틀 설정
plt.show()

# %%
use_col=['cossim_f1', 'manhattan_f1', 'euclidean_f1', 'dot_f1']

df_final=df[use_col]


fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성

for i in use_col:
  ax.plot(df_final[i], label=i) ## 선그래프 생성
plt.legend()

plt.ylim([0.9, 0.935])

plt.title('f1',fontsize=20) ## 타이틀 설정
plt.show()
